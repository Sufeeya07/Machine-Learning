# %% [markdown]
# # Standardization

# %% [markdown]
# ## manual approach

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
total_bill = df['total_bill'].tolist()

# %%
mean = np.mean(total_bill)
std = np.std(total_bill)

# %%
mean, std
# Out:
# (np.float64(19.78594262295082), np.float64(8.884150577771132))

# %%
normalized_data =[]

for i in total_bill:
    z_score = (i-mean)/std
    normalized_data.append(z_score)
    
    print(f'{len(normalized_data)} : The element is : {normalized_data} \n')
    
    
print( normalized_data)
# Out:
# 1 : The element is : [np.float64(-0.3147113050904943)]
#
# 2 : The element is : [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692)]
#
# 3 : The element is : [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145)]
#
# 4 : The element is : [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145), np.float64(0.43831510316725475)]
#
# 5 : The element is : [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145), np.float64(0.43831510316725475), np.float64(0.540744704290506)]
#
# 6 : The element is : [np.float64(-0.3147113050904943), np.float64(-1.0632353132988692), np.float64(0.13777989987156145), np.float64(0.43831510316725475), np.float64(0.540744704290506), np.float64(0.6195367051545455)]
#
# ...

# %%
len(normalized_data)
# Out:
# 244

# %%
sns.histplot(total_bill)

plt.title('Before Standardization')
# Out:
# Text(0.5, 1.0, 'Before Standardization')

# %%
plt.figure(figsize=(10,4))
sns.histplot(normalized_data)

plt.title('After Standardization')
# Out:
# Text(0.5, 1.0, 'After Standardization')

# %%
# Plot original data
sns.histplot(total_bill, color='blue', label='Original Data', kde=True)

# Plot normalized data
sns.histplot(normalized_data, color='red', label='Normalized Data', kde=True)

# Add labels and legend
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()
plt.title("Comparison of Original and Normalized Data")

# Show the plot
plt.show()

# %% [markdown]
# # second approach with StandardScaler class

# %%
from sklearn.preprocessing import StandardScaler

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(df[['total_bill' , 'tip']])
# Out:
# StandardScaler()

# %%
# transfrom is helps to apply z- score formula

pd.DataFrame(scaler.transform(df[['total_bill' , 'tip']]), columns=['total_bill', 'tips'])
# Out:
#      total_bill      tips
# 0     -0.314711 -1.439947
# 1     -1.063235 -0.969205
# 2      0.137780  0.363356
# 3      0.438315  0.225754
# 4      0.540745  0.443020
# ..          ...       ...
# 239    1.040511  2.115963
# 240    0.832275 -0.722971
# 241    0.324630 -0.722971
# 242   -0.221287 -0.904026
# 243   -0.113229  0.001247
#
# [244 rows x 2 columns]
