# %% [markdown]
# # Support Vector Regressor

# %%
from sklearn.svm import SVR
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X, y= make_regression(n_samples= 100, n_features=1, noise=10)

# %%
X , y
# Out:
# (array([[-9.17338570e-01],
#         [-1.86509601e+00],
#         [ 1.48435822e+00],
#         [ 6.87574927e-01],
#         [-9.34889559e-01],
#         [ 6.25136037e-01],
#         [ 4.73372974e-01],
#         [ 5.97463809e-01],
#         [ 1.06995015e-01],
#         [-3.93801089e-01],
#         [ 2.82626698e-01],
#         [-1.39240674e+00],
#         [-7.85670130e-01],
#         [-1.65327419e+00],
#         [ 1.61175007e+00],
#         [ 3.68269517e-01],
#         [ 1.50036362e+00],
#         [-1.40233193e+00],
#         [-1.20580898e+00],
#         [ 2.35682734e+00],
#         [ 1.58969905e-01],
#         [ 4.00933347e-01],
#         [-1.22939918e+00],
#         [-4.57159622e-01],
#         [ 1.92166702e-01],
#         [-2.55126761e-01],
#         [-8.36636500e-01],
#         [ 2.15558936e+00],
#         [-5.86104301e-01],
#         [ 7.12960416e-01],
#         [ 6.97552112e-01],
#         [-1.50958413e+00],
#         [-1.52927395e+00],
#         [-1.70794026e-01],
#         [-8.15702277e-02],
#         [-1.31073137e+00],
#         [-6.96601253e-02],
#         [ 1.25948385e-01],
#         [-3.59895372e-01],
#         [-1.08011469e+00],
#         [ 1.57169123e-01],
#         [ 1.01072604e+00],
#         [ 2.52050064e+00],
#         [ 1.50162876e+00],
#         [-1.00748195e+00],
#         [ 1.91362539e-02],
#         [-4.34635263e-01],
#         [-5.71074064e-01],
#         [-1.64744366e-01],
#         [ 7.10472998e-01],
#         [ 1.61843656e+00],
#         [-7.77452600e-01],
#         [-6.67871269e-01],
#         [-4.43651856e-01],
#         [-1.53768138e+00],
#         [-7.17908841e-01],
#         [ 7.65168917e-01],
#         [-1.29816710e+00],
#         [ 1.00447687e+00],
#         [-8.20588867e-01],
#         [-2.31999826e+00],
#         [-1.65827179e-01],
#         [ 7.41528445e-01],
#         [ 1.36940673e-01],
#         [-5.49890465e-01],
#         [ 7.11108948e-01],
#         [ 3.80932631e-01],
#         [-2.54757124e-01],
#         [ 9.47830869e-01],
#         [-3.42884872e-01],
#         [ 8.24176239e-01],
#         [ 1.37609011e+00],
#         [-1.01510872e+00],
#         [ 7.03309074e-01],
#         [ 1.28988345e-03],
#         [ 3.92774372e-01],
#         [-7.85967193e-01],
#         [-9.68077495e-02],
#         [-5.48321495e-01],
#         [-1.55423473e-01],
#         [ 9.75620413e-01],
#         [ 8.78635989e-01],
#         [-5.46925065e-01],
#         [ 1.05149756e+00],
#         [-6.68406975e-01],
#         [ 6.73709194e-02],
#         [ 9.59885022e-01],
#         [-1.11743519e+00],
#         [ 6.47507642e-01],
#         [ 4.62412779e-01],
#         [ 9.74082644e-01],
#         [ 7.91711420e-01],
#         [-4.61294244e-01],
#         [ 6.60077624e-02],
#         [ 5.03938235e-01],
#         [ 8.09856645e-01],
#         [ 9.77383436e-01],
#         [-1.26385354e+00],
#         [-1.41860679e+00],
#         [-1.07689869e-01]]),
#  array([ -69.30204968, -132.52746273,   91.53531755,   42.99963398,
#          -62.32523975,   53.2157808 ,   37.9633826 ,   36.8192618 ,
#            2.88276474,  -39.79473689,   17.25558354, -108.69757015,
#          -52.19789687, -108.94971433,  117.71983503,   17.31439131,
#          105.63864207,  -99.06412289,  -52.29287575,  151.97483319,
#            8.71372376,   31.48592447,  -79.1949294 ,  -28.36923913,
#           -4.09838543,  -10.1923894 ,  -58.39183754,  139.21537258,
#          -37.19214626,   60.05670176,   65.36312886, -100.83429035,
#          -94.16330949,   -1.04781625,   14.27420573,  -98.77346347,
#            9.88525123,   -0.84296973,  -19.67522328,  -57.59327217,
#            8.45367102,   76.6512556 ,  167.11619274,  100.18114883,
#          -70.87825332,   15.37751813,  -40.39148252,  -46.37210092,
#           -8.8533645 ,   68.77053595,  112.32175264,  -39.52484099,
#          -50.90557537,  -26.99778142, -115.4397156 ,  -55.78407235,
#           42.48513388,  -85.76337804,   59.68586102,  -68.08301117,
#         -165.86972115,  -11.22926342,   39.6727428 ,    2.65653571,
#          -29.10620034,   54.18521197,   22.15805713,  -22.45774206,
#           60.034193  ,  -26.39597202,   43.01628158,   88.60085481,
#          -63.76219255,   40.21649431,    1.31516653,   22.47266487,
#          -69.99598577,    2.49567281,  -41.37017091,   -5.25711913,
#           54.07066518,   80.60859765,  -26.35770037,   63.05674844,
#          -46.91979086,   25.2394365 ,   47.81756492,  -77.34003084,
#           35.70809   ,   50.70928445,   60.11695692,   50.7242212 ,
#          -38.31504187,    6.17298986,   39.29142894,   37.46202678,
#           52.32574002,  -80.15691368,  -74.18093276,   -1.43577667]))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model= SVR(kernel='rbf' , C=100, epsilon=10)
model
# Out:
# SVR(C=100, epsilon=10)

# %%
model.fit(X_train, y_train)
# Out:
# SVR(C=100, epsilon=10)

# %%
# prediction 

pred = model.predict(X_test)
print('Mean Squared Error', mean_squared_error(y_test, pred))
# Out:
# Mean Squared Error 85.42513683056514
